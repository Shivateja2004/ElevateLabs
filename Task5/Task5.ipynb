# %%
# ============================
# TASK 5: Data Analysis in COLAB
# ============================

# STEP 1: IMPORT LIBRARIES
import pandas as pd
import matplotlib.pyplot as plt

# STEP 2: UPLOAD CSV FILE
from google.colab import files
uploaded = files.upload()

# The uploaded file will appear in 'uploaded' dict
filename = list(uploaded.keys())[0]
print("Loaded File:", filename)

# STEP 3: LOAD CSV INTO DATAFRAME
df = pd.read_csv(filename)
df.head()

# %%
print("Shape of DataFrame:", df.shape)
print("\nColumns:", df.columns.tolist())
df.info()

# %%
sales_by_product = df.groupby("Product")["Sales"].sum()
sales_by_product

# %%
sales_by_product.plot(
    kind="bar",
    figsize=(8,5),
    title="Total Sales by Product"
)
plt.xlabel("Product")
plt.ylabel("Sales")
plt.show()

# %%
# Example: filter rows where Sales > 5000
filtered_df = df[df["Sales"] > 5000]
filtered_df

# %%
print("Using loc:", df.loc[0])
print("\nUsing iloc:", df.iloc[0])

# %%
df.isna().sum()
